# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/salary-dataset-simple-linear-regression/Salary_dataset.csv')

# %%
df.head()

# %%
X = df[['YearsExperience']]

# %%
y = df[['Salary']]

# %%
X.head()

# %%
y.head()

# %%
from sklearn.model_selection import train_test_split

train_X,test_X,train_y,test_y=train_test_split(X,y,test_size=0.2,shuffle=True)

# %%
train_X.shape

# %%
import matplotlib.pyplot as plt

plt.scatter(train_X,train_y)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(train_X,train_y)

# %%
predicted_values= model.predict(X)
plt.scatter(X,y)
plt.plot(X,predicted_values,color="red")

# %%
from sklearn.metrics import r2_score

y_predicted = model.predict(test_X)
r2=r2_score(test_y, y_predicted)
print(r2)

# %%
model.fit(train_X, train_y)
print(model.coef_)
print(model.intercept_)

# %%
# Lets apply Gradient Descent assuming slope is constant m = 9319.94022518
# and let's assume the starting value for intercept b = 0
X_array = X.to_numpy().flatten()
y_pred = 9319.94022518 * X_array + 100

# %%
plt.scatter(X,y)
plt.plot(X,model.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='#00a65a',label='b = 0')
plt.legend()
plt.show()

# %%
m = 9319.94022518
b = 100

loss_slope = -2 * np.sum(y.values.ravel() - m * X.values.ravel() - b)

loss_slope

# %%
# Lets take learning rate = 0.01
lr = 0.01

step_size = loss_slope*lr
step_size

# %%
# Calculating the new intercept
b = b - step_size
b

# %%
y_pred1 = (9319.94022518 * X.values.ravel()) + b

plt.scatter(X,y)
plt.plot(X,model.predict(X),color='red',label='OLS')
plt.plot(X,y_pred1,color='#00a65a',label='b (pred1)')
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
# Iteration 2
loss_slope = -2 * np.sum(y.values.ravel() - m * X.values.ravel() - b)

loss_slope

# %%
lr = 0.01

step_size = loss_slope*lr
step_size

# %%
# Calculating the new intercept
b = b - step_size
b

# %%
y_pred2 = (9319.94022518 * X.values.ravel()) + b

plt.scatter(X,y)
plt.plot(X,model.predict(X),color='red',label='OLS')
plt.plot(X, y_pred2, color='#A3E4D7', label='b (pred2)')
plt.plot(X, y_pred1, color='#A3E4D7', label='b (pred1)')
plt.plot(X, y_pred, color='#A3E4D7', label='b = 0')
plt.legend()
plt.show()

# %%
# Iteration 3

loss_slope = -2 * np.sum(y.values.ravel() - m * X.values.ravel() - b)

loss_slope

# %%
lr = 0.01

step_size = loss_slope*lr
step_size

# %%
# Calculating the new intercept
b = b - step_size
b

# %%
y_pred3 = (9319.94022518 * X.values.ravel()) + b

plt.figure(figsize=(15,15))
plt.scatter(X,y)
plt.plot(X, model.predict(X), color='red', label='OLS')
plt.plot(X, y_pred3, color='#00a65a', label='b (pred3)')
plt.plot(X, y_pred2, color='#A3E4D7', label='b (pred2)')
plt.plot(X, y_pred1, color='#A3E4D7', label='b (pred1)')
plt.plot(X, y_pred, color='#A3E4D7', label='b = 0')
plt.legend()
plt.show()

# %%
# Iteration 4

loss_slope = -2 * np.sum(y.values.ravel() - m * X.values.ravel() - b)

loss_slope

# %%
lr = 0.01

step_size = loss_slope*lr
step_size

# %%
# Calculating the new intercept
b = b - step_size
b

# %%
y_pred4 = (9319.94022518 * X.values.ravel()) + b

plt.figure(figsize=(15, 15))
plt.scatter(X, y)
plt.plot(X, model.predict(X), color='red', label='OLS')
plt.plot(X, y_pred3, color='#00a65a', label='b (pred3)')
plt.plot(X, y_pred2, color='#A3E4D7', label='b (pred2)')
plt.plot(X, y_pred1, color='#A3E4D7', label='b (pred1)')
plt.plot(X, y_pred, color='#A3E4D7', label='b = 0')
plt.plot(X, y_pred4, color='blue', label='b (pred4))')

plt.legend()
plt.show()

# %%
# Iteration 5

loss_slope = -2 * np.sum(y.values.ravel() - m * X.values.ravel() - b)

loss_slope

# %%
lr = 0.01

step_size = loss_slope*lr
step_size

# %%
# Calculating the new intercept
b = b - step_size
b

# %%
y_pred5 = (9319.94022518 * X.values.ravel()) + b

plt.figure(figsize=(15, 15))
plt.scatter(X, y)
plt.plot(X, model.predict(X), color='red', label='OLS')
plt.plot(X, y_pred3, color='#00a65a', label='b (pred3)')
plt.plot(X, y_pred2, color='#A3E4D7', label='b (pred2)')
plt.plot(X, y_pred1, color='#A3E4D7', label='b (pred1)')
plt.plot(X, y_pred, color='#A3E4D7', label='b = 0')
plt.plot(X, y_pred4, color='blue', label='b (pred4))')
plt.plot(X, y_pred5, color='purple', label='b (pred5)')

plt.legend()
plt.show()

# %%
# Iteration 6

loss_slope = -2 * np.sum(y.values.ravel() - m * X.values.ravel() - b)

loss_slope

# %%
lr = 0.01

step_size = loss_slope*lr
step_size

# %%
# Calculating the new intercept
b = b - step_size
b

# %%
y_pred6 = (9319.94022518 * X.values.ravel()) + b 

plt.figure(figsize=(15, 15))
plt.scatter(X, y)

plt.plot(X, model.predict(X), color='red', label='OLS')
plt.plot(X, y_pred3, color='#00a65a', label='b (pred3)')
plt.plot(X, y_pred2, color='#A3E4D7', label='b (pred2)')
plt.plot(X, y_pred1, color='#A3E4D7', label='b (pred1)')
plt.plot(X, y_pred, color='#A3E4D7', label='b = 0')
plt.plot(X, y_pred4, color='blue', label='b (pred4)')
plt.plot(X, y_pred5, color='purple', label='b (pred5)')
plt.plot(X, y_pred6, color='orange', label='b (pred6)')

plt.legend()
plt.show()

# %%
# Initial values
m = 9319.94022518  # fixed slope
b = 0              # initial intercept
lr = 0.01          # learning rate
epochs = 100       # number of iterations

# For tracking b values over epochs (optional)
b_values = []

for i in range(epochs):
    # Compute the gradient (loss_slope)
    loss_slope = -2 * np.sum(y.values.ravel() - m * X.values.ravel() - b)

    # Step size
    step_size = loss_slope * lr

    # Update intercept
    b = b - step_size

    # Store for analysis
    b_values.append(b)

    # Optional: Print intermediate values
    print(f"Epoch {i+1:3}: b = {b:.4f}, step size = {step_size:.4f}, loss_slope = {loss_slope:.4f}")
